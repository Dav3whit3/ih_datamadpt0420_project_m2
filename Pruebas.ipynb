# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import cufflinks as cf

# %matplotlib inline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
diamonds = pd.read_csv('/home/david/Documents/data/diamonds_train.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %%
diamonds['cut'].unique()

# %%
a = diamonds.groupby('color').count().reset_index()
a
# Out:
#   color  carat   cut  clarity  depth  table  price     x     y     z
# 0     D   5049  5049     5049   5049   5049   5049  5049  5049  5049
# 1     E   7325  7325     7325   7325   7325   7325  7325  7325  7325
# 2     F   7177  7177     7177   7177   7177   7177  7177  7177  7177
# 3     G   8455  8455     8455   8455   8455   8455  8455  8455  8455
# 4     H   6277  6277     6277   6277   6277   6277  6277  6277  6277
# 5     I   4032  4032     4032   4032   4032   4032  4032  4032  4032
# 6     J   2140  2140     2140   2140   2140   2140  2140  2140  2140

# %%
fig, axes = plt.subplots(ncols=1, nrows=1, figsize=(8, 4))
axes.barh(a['color'], a['carat'])
plt.tight_layout(5)

axes.set(xlim=[0, 15000],
           title='Diamonds per color',
           ylabel='Color type',
           xlabel='nº of diamonds')

axes.axvline(8000, ls=':')

# %%
diamonds.describe(include='all')
# Out:
#                carat    cut  color clarity         depth         table  \
# count   40455.000000  40455  40455   40455  40455.000000  40455.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  16220   8455    9749           NaN           NaN
# mean        0.797706    NaN    NaN     NaN     61.752841     57.446133
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# count   40455.000000  40455.000000  40455.000000  40455.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean     3928.444469      5.729392      5.732819      3.537154
# std      3992.416147      1.124453      1.146650      0.697062
# min       326.000000      0.000000      0.000000      0.000000
# 25%       945.000000      4.710000      4.720000      2.910000
# 50%      2397.000000      5.690000      5.710000      3.520000
# 75%      5331.000000      6.540000      6.540000      4.035000
# max     18823.000000     10.230000     58.900000      8.060000

# %%
diamonds.boxplot(figsize=(16, 8))

# %%
diamonds[['price']].plot(kind='box', figsize=(8, 8), grid=True)

# %%
diamonds.loc[diamonds[['price']].idxmax(), :]

# %%
fig = go.Figure(data=[go.Mesh3d(x=([0.5, 0.2, 0.4, 0.6, 0.8, 0.6, 0.4]),
                   y=([0.4, 0.4, 0.2, 0.2, 0.4, 0.6, 0.6]),
                   z=([0, 0.4, 0.4, 0.4, 0.4, 0.4, 0.
000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  16220   8455    9749           NaN           NaN
# mean        0.797706    NaN    NaN     NaN     61.752841     57.446133
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# count   40455.000000  40455.000000  40455.000000  40455.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean     3928.444469      5.729392      5.732819      3.537154
# std      3992.416147      1.124453      1.146650      0.697062
# min       326.000000      0.000000      0.000000      0.000000
# 25%       945.000000      4.710000      4.720000      2.910000
# 50%      2397.000000      5.690000      5.710000      3.520000
# 75%      5331.000000      6.540000      6.540000      4.035000
# max     18823.000000     10.230000     58.900000      8.060000

# %%
desc.index
# Out:
# Index(['count', 'unique', 'top', 'freq', 'mean', 'std', 'min', '25%', '50%',
#        '75%', 'max'],
#       dtype='object')

# %%
new_col = list(desc.index)
new_col
# Out:
# ['count',
#  'unique',
#  'top',
#  'freq',
#  'mean',
#  'std',
#  'min',
#  '25%',
#  '50%',
#  '75%',
#  'max']

# %%
desc.insert(loc=0, column='Stats', value=new_col)

# %%
desc
# Out:
#          Stats         carat    cut  color clarity         depth  \
# count    count  40455.000000  40455  40455   40455  40455.000000
# unique  unique           NaN      5      7       8           NaN
# top        top           NaN  Ideal      G     SI1           NaN
# freq      freq           NaN  16220   8455    9749           NaN
# mean      mean      0.797706    NaN    NaN     NaN     61.752841
# std        std      0.475544    NaN    NaN     NaN      1.431725
# min        min      0.200000    NaN    NaN     NaN     43.000000
# 25%        25%      0.400000    NaN    NaN     NaN     61.000000
# 50%        50%      0.700000    NaN    NaN     NaN     61.800000
# 75%        75%      1.040000    NaN    NaN     NaN     62.500000
# max        max      4.500000    NaN    NaN     NaN     79.000000
#
#                table         price             x             y             z
# count   40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       57.446133   3928.444469      5.729392      5.732819      3.537154
# std         2.233535   3992.416147      1.124453      1.146650      0.697062
# min        43.000000    326.000000      0.000000      0.000000      0.000000
# 25%        56.000000    945.000000      4.710000      4.720000      2.910000
# 50%        57.000000   2397.000000      5.690000      5.710000      3.520000
# 75%        59.000000   5331.000000      6.540000      6.540000      4.035000
# max        95.000000  18823.000000     10.230000     58.900000      8.060000

# %%
diamonds['color'].unique()
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
diamonds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
diamonds.select_dtypes(include=np.object).columns.to_list()
# Out:
# ['cut', 'color', 'clarity']

# %%
a = 5

# %%
def cambio():
    a = 3

# %%
cambio()

# %%
a
# Out:
# 5
