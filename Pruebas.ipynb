# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import cufflinks as cf

# %matplotlib inline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
diamonds = pd.read_csv('/home/david/Documents/data/diamonds_train.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %%
diamonds['cut'].unique()

# %%
a = diamonds.groupby('color').count().reset_index()
a

# %%
fig, axes = plt.subplots(ncols=1, nrows=1, figsize=(8, 4))
axes.barh(a['color'], a['carat'])
plt.tight_layout(5)

axes.set(xlim=[0, 15000],
           title='Diamonds per color',
           ylabel='Color type',
           xlabel='nº of diamonds')

axes.axvline(8000, ls=':')

# %%
diamonds.describe(include='all')

# %%
diamonds.boxplot(figsize=(16, 8))

# %%
diamonds[['price']].plot(kind='box', figsize=(8, 8), grid=True)

# %%
diamonds.loc[diamonds[['price']].idxmax(), :]

# %%
fig = go.Figure(data=[go.Mesh3d(x=([0.5, 0.2, 0.4, 0.6, 0.8, 0.6, 0.4]),
                   y=([0.4, 0.4, 0.2, 0.2, 0.4, 0.6, 0.6]),
                   z=([0, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4]),
                   opacity=0.5,
                   color='rgba(244,22,100,0.6)'
                  )])
fig

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=diamonds['price'],
                                  marker_color='#EB89B5',
                                  opacity=0.75,
                                  
                           
                          ))

# %%
diamonds.head(5)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
d = diamonds.groupby('cut').mean().reset_index()[['cut', 'price']]
d
# Out:
#          cut        price
# 0       Fair  4333.271980
# 1       Good  3880.611794
# 2      Ideal  3436.112577
# 3    Premium  4617.322612
# 4  Very Good  3994.444420

# %%
f = diamonds[['depth', 'price']].groupby('depth').mean().reset_index()
f

h = diamonds[['table', 'price']].groupby('table').mean().reset_index()
h

y = diamonds[['carat', 'price']].groupby('carat').mean().reset_index()

# %%
y
# Out:
#      carat         price
# 0     0.20    363.333333
# 1     0.21    380.222222
# 2     0.22    391.400000
# 3     0.23    487.261682
# 4     0.24    506.778378
# ..     ...           ...
# 265   3.51  18701.000000
# 266   4.00  15984.000000
# 267   4.01  15223.000000
# 268   4.13  17329.000000
# 269   4.50  18531.000000
#
# [270 rows x 2 columns]

# %%
t['depth']
# Out:
# 0      43.0
# 1      44.0
# 2      52.3
# 3      52.7
# 4      53.3
#        ...
# 170    71.8
# 171    72.2
# 172    72.9
# 173    73.6
# 174    79.0
# Name: depth, Length: 175, dtype: float64

# %%
figure = go.Figure()
figure.add_trace(go.Scatter(x=f['depth'],
                            y=f['price']))

figure.add_trace(go.Scatter(x=h['table'],
                            y=h['price']))

figure.add_trace(go.Scatter(x=y['carat'],
                            y=y['price']))
figure.update_layout(yaxis_tickformat = '%')
# Out:
# <div>
#
#
#             <div id="42b43894-9775-4df2-b748-ef30a0d34496" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById